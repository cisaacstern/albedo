# %%
import panel as pn
pn.extension()
import _albedo.dashlayout as dashlayout

dash = dashlayout.DashLayout()
dash.dashboard()
# Out:
# Column
#     [0] Row
#         [0] ParamMethod(method)
#         [1] ParamMethod(method)
#         [2] ParamMethod(method)
#         [3] ParamMethod(method)
#         [4] ParamMethod(method)
#         [5] ParamMethod(method)
#         [6] ParamMethod(method)
#         [7] ParamMethod(method)
#         [8] ParamMethod(method)
#     [1] Row
#         [0] Tabs(tabs_location='left')
#             [0] Markdown(str, name='README')
#             [1] Column(name='Configure')
#                 [0] Markdown(str)
#                 [1] Tabs
#                     [0] Column(name='Date')
#                         [0] Row
#                             [0] WidgetBox
#                                 [0] Param(DashLayout, name='File', parameters=['date'], widgets={'date': {'widget_type': <...}, width=200)
#                             [1] WidgetBox
#                                 [0] Row
# ...
