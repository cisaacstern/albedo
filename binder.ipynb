# %%
import panel as pn

# %%
m = pn.widgets.MultiSelect(name='Measurements', value=['Global Up', 'Direct Dwn'],
    options=['Global Up', 'Direct Dwn', 'Diffuse Dwn'], size=3, width=110)

p = pn.widgets.MultiSelect(name='Planar', value=['M', 'Alpha'],
    options=['M', 'Alpha', 'IDR'], size=3, width=70)

r = pn.widgets.MultiSelect(name='Raster', value=['M', 'Alpha'],
    options=['M', 'Alpha', 'IDR'], size=3, width=70)

toggle = pn.widgets.Toggle(name='Toggle', button_type='default', 
                           width=40)

h = pn.widgets.MultiSelect(name='Horizon', value=['M', 'Alpha'],
    options=['M', 'Alpha', 'IDR'], size=3, width=70)

f = pn.widgets.MultiSelect(name='Fill between', value=['> Selected M\'s', '> Selected Alpha\'s'],
    options=['> Selected M\'s', '> Selected Alpha\'s', '> Selected IDR\'s'], size=3, width=140)

wb = pn.WidgetBox(pn.Row(m, p, r, h, f, pn.Column('Shade %',toggle)), width=645, height=85, name='h')

wb

# %%
import panel as pn
pn.extension()
import _albedo.dashlayout as dashlayout

dash = dashlayout.DashLayout()
dash.dashboard()
# Out:
# Column
#     [0] Row
#         [0] ParamMethod(method)
#         [1] ParamMethod(method)
#         [2] ParamMethod(method)
#         [3] ParamMethod(method)
#         [4] ParamMethod(method)
#         [5] ParamMethod(method)
#         [6] ParamMethod(method)
#         [7] ParamMethod(method)
#     [1] Row
#         [0] Tabs
#             [0] Row(name='Initialize')
#                 [0] Column
#                     [0] Markdown(str)
#                     [1] JSON(dict, hover_preview=True, width=300)
#                 [1] Column
#                     [0] Row
#                         [0] WidgetBox
#                             [0] Param(DashLayout, name='File', parameters=['date'], widgets={'date': {'widget_type': <...}, width=120)
#                         [1] WidgetBox
#                             [0] Row
#                                 [0] Param(DashLayout, name='View', parameters=['choose3d'], widgets={'choose3d': {'widget_type...}, width=100)
# ...
