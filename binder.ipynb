# %%
import itertools

# %%
date_dict = {}
for index, date in enumerate(dash.enabledDays, start=0):
    date_string = date.strftime("%Y-%m-%d")
    date_dict[date_string] = index

# %%
discrete_slider = pn.widgets.DiscreteSlider(name='Discrete Slider', options=date_dict, value=0)

discrete_slider

# %%
import panel as pn
pn.extension()
import _albedo.dashlayout as dashlayout

dash = dashlayout.DashLayout()
dash.dashboard()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-1-e4302e415440> in <module>
#       4
#       5 dash = dashlayout.DashLayout()
# ----> 6 dash.dashboard()
#
# ~/Dropbox/CUES2020/LIDAR2020/github/albedo/_albedo/dashlayout.py in dashboard(self)
#     170         self.set_json()
#     171         self.set_controls()
# --> 172         self.set_layout()
#     173         return pn.Column(self.function_row,
#     174                          self.model_tabs)
#
# ~/Dropbox/CUES2020/LIDAR2020/github/albedo/_albedo/dashlayout.py in set_layout(self)
#     103                    width=900
#     104                   ),
# --> 105             pn.Column(pn.Row(self.polarAxes, self.plotMRaster, self.plotMask),
#     106                       name='Terrain Correction Preview',
#     107                       width=900
#
# ...
