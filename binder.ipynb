# %%
import panel as pn
pn.extension()
import _albedo.dashlayout as dashlayout

dash = dashlayout.DashLayout()
dash.dashboard()
# Out:
# Column
#     [0] Row
#         [0] ParamMethod(method)
#         [1] ParamMethod(method)
#         [2] ParamMethod(method)
#         [3] ParamMethod(method)
#         [4] ParamMethod(method)
#         [5] ParamMethod(method)
#         [6] ParamMethod(method)
#         [7] ParamMethod(method)
#     [1] Row
#         [0] Tabs
#             [0] Row(name='Initialize')
#                 [0] Column
#                     [0] Markdown(str)
#                     [1] JSON(dict, hover_preview=True, width=300)
#                 [1] Column
#                     [0] Row
#                         [0] WidgetBox
#                             [0] Param(DashLayout, name='File', parameters=['date'], widgets={'date': {'widget_type': <...}, width=120)
#                         [1] WidgetBox
#                             [0] Row
#                                 [0] Param(DashLayout, name='View', parameters=['choose3d'], widgets={'choose3d': {'widget_type...}, width=100)
# ...
